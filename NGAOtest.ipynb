# %%
from NGAO import *

# %matplotlib inline
import IPython

# %%
inputFolder = './'
parametersFileName = 'params'
ngaoSimulation = NGAO(inputFolder, parametersFileName)
print(ngaoSimulation.GPUnum)
# ngaoSimulation.closedLoopSimul()
ngaoSimulation.runAll()
ngaoSimulation.saveTN()
# Out:
# ./params.ini
# M2 modes loaded from:512
# (@CEO)>Pyramid: Set modulation sampling to 24
# Number of NGAO GS photons/s/m^2: 2445999.8
# Number of expected NGAO GS photons [ph/s/m^2]: 2445652.2
# Number of pixels across 25.5-m array: 920
# 1
# (65536, 1350)
# RMS of KL mode 100 is: 0.50
# Center of subpupil images (pix):
# [[117.5 117.5]
#  [117.5 249.5]
#  [249.5 117.5]
#  [249.5 249.5]]
# ->     Number of valid SAs: 5408
# /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# Reading file: /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# AO WFS - M2 Segment Modal IM:
# (10816, 4725)
# AO WFS - M2 Segment Modal IM:
# (10816, 3500)
# Condition number: 24.288437
# AO SH WFS - M2 Segment Modal Rec:
# (3499, 10816)
# AO SH WFS - M2 Segment Modal Rec:
# (3500, 10816)
# KL0 - SPS IM:
# ___ M2 ___ (Karhunen-Loeve)
# Segment #0: 1
# Segment #1: 1
# Segment #2: 1
# Segment #3: 1
# ...

# %%
inputFolder = './'
parametersFileName = 'params'
ngaoSimulation1 = NGAO(inputFolder, parametersFileName)
ngaoSimulation1.loadTN('20210527_183107')
# Out:
# ./params.ini
# M2 modes loaded from:512
# (@CEO)>Pyramid: Set modulation sampling to 24
# Number of NGAO GS photons/s/m^2: 2445999.8
# Number of expected NGAO GS photons [ph/s/m^2]: 2445652.2
# Number of pixels across 25.5-m array: 920

# %%
ngaoSimulation1.analyseSimulation()
# Out:
# Center of subpupil images (pix):
# [[117.5 117.5]
#  [117.5 249.5]
#  [249.5 117.5]
#  [249.5 249.5]]
# ->     Number of valid SAs: 5408
# (65536, 1350)
# RMS of KL mode 100 is: 0.50
# /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# Reading file: /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# AO WFS - M2 Segment Modal IM:
# (10816, 4725)
#       Final WFE [nm RMS]: nan
#       Final SPP RMS [nm]: nan
# Equivalent SR @ 1.65 um: nan
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3372: RuntimeWarning: Mean of empty slice.
# ...
