# %%
from NGAO import *

# %matplotlib inline
import IPython

# %%
inputFolder = '/home/frossi/CEO/'
parametersFileName = 'params'
ngaoSimulation = NGAO(inputFolder, parametersFileName)
ngaoSimulation.runAll()
ngaoSimulation.saveTN()
# Out:
# /home/frossi/CEO/params.ini
# M2 modes loaded from:512
# (@CEO)>Pyramid: Set modulation sampling to 24
# Number of NGAO GS photons/s/m^2: 2445999.8
# Number of expected NGAO GS photons [ph/s/m^2]: 2445652.2
# Number of pixels across 25.5-m array: 920
# (65536, 1350)
# RMS of KL mode 100 is: 0.51
# Center of subpupil images (pix):
# [[117.5 117.5]
#  [117.5 249.5]
#  [249.5 117.5]
#  [249.5 249.5]]
# ->     Number of valid SAs: 5408
# /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# Reading file: /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# AO WFS - M2 Segment Modal IM:
# (10816, 4725)
# AO WFS - M2 Segment Modal IM:
# (10816, 3500)
# Condition number: 24.288437
# AO SH WFS - M2 Segment Modal Rec:
# (3499, 10816)
# AO SH WFS - M2 Segment Modal Rec:
# (3500, 10816)
# KL0 - SPS IM:
# ___ M2 ___ (Karhunen-Loeve)
# Segment #0: 1
# Segment #1: 1
# Segment #2: 1
# Segment #3: 1
# Segment #4: 1
# Segment #5: 1
# Segment #6: 1
# ------------
# [  6  39 104 191 317 459]
# [ 3  7 11 15 19 23]
#        Mean wind speed : 13.5 m/s
#                   tau0 : 2.41 ms
#     r0 @ 500nm @ 30 deg: 10.4 cm
# seeing @ 500nm @ 30 deg: 0.97 arcsec
# Number of valid mask points over each segment:
#  [69146 69146 69163 69146 69146 69163 50712]
# 12
# WF RMS of PTT modes:
# [1. 1. 1.]
#  iter: 147/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1198.9  Optical Gain of mode S0 KL6: 0.217
#   Optical Gain of mode S1 KL39: 0.394
#   Optical Gain of mode S2 KL104: 0.509
#   Optical Gain of mode S3 KL191: 0.756
#   Optical Gain of mode S4 KL317: 0.645
#   Optical Gain of mode S5 KL459: 0.593
#  iter: 196/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1283.1  Optical Gain of mode S0 KL6: 0.336
#   Optical Gain of mode S1 KL39: 0.408
#   Optical Gain of mode S2 KL104: 0.702
#   Optical Gain of mode S3 KL191: 0.628
#   Optical Gain of mode S4 KL317: 0.538
#   Optical Gain of mode S5 KL459: 0.629
#  iter: 245/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1383.5  Optical Gain of mode S0 KL6: 0.563
#   Optical Gain of mode S1 KL39: 0.753
#   Optical Gain of mode S2 KL104: 0.651
#   Optical Gain of mode S3 KL191: 0.917
#   Optical Gain of mode S4 KL317: 0.827
#   Optical Gain of mode S5 KL459: 1.183
#  iter: 294/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1576.5  Optical Gain of mode S0 KL6: 0.526
#   Optical Gain of mode S1 KL39: 0.646
#   Optical Gain of mode S2 KL104: 0.807
#   Optical Gain of mode S3 KL191: 0.964
#   Optical Gain of mode S4 KL317: 0.734
#   Optical Gain of mode S5 KL459: 0.786
#  iter: 343/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1715.9  Optical Gain of mode S0 KL6: 0.818
#   Optical Gain of mode S1 KL39: 0.698
#   Optical Gain of mode S2 KL104: 0.681
#   Optical Gain of mode S3 KL191: 0.614
#   Optical Gain of mode S4 KL317: 0.665
#   Optical Gain of mode S5 KL459: 0.952
#  iter: 392/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1736.2  Optical Gain of mode S0 KL6: 0.691
#   Optical Gain of mode S1 KL39: 0.749
#   Optical Gain of mode S2 KL104: 0.742
#   Optical Gain of mode S3 KL191: 0.817
#   Optical Gain of mode S4 KL317: 1.073
#   Optical Gain of mode S5 KL459: 0.797
#  iter: 441/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1629.0  Optical Gain of mode S0 KL6: 0.853
#   Optical Gain of mode S1 KL39: 0.900
#   Optical Gain of mode S2 KL104: 0.755
#   Optical Gain of mode S3 KL191: 0.666
#   Optical Gain of mode S4 KL317: 0.631
#   Optical Gain of mode S5 KL459: 1.108
#  iter: 490/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1702.5  Optical Gain of mode S0 KL6: 1.019
#   Optical Gain of mode S1 KL39: 0.573
#   Optical Gain of mode S2 KL104: 0.696
#   Optical Gain of mode S3 KL191: 0.922
#   Optical Gain of mode S4 KL317: 0.825
#   Optical Gain of mode S5 KL459: 0.844
#  iter: 539/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1776.5  Optical Gain of mode S0 KL6: 0.910
#   Optical Gain of mode S1 KL39: 0.895
#   Optical Gain of mode S2 KL104: 0.993
#   Optical Gain of mode S3 KL191: 0.733
#   Optical Gain of mode S4 KL317: 1.203
#   Optical Gain of mode S5 KL459: 0.589
#  iter: 588/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1824.4  Optical Gain of mode S0 KL6: 0.970
#   Optical Gain of mode S1 KL39: 1.023
#   Optical Gain of mode S2 KL104: 1.191
#   Optical Gain of mode S3 KL191: 0.889
#   Optical Gain of mode S4 KL317: 1.358
#   Optical Gain of mode S5 KL459: 0.832
#  iter: 637/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1915.1  Optical Gain of mode S0 KL6: 0.640
#   Optical Gain of mode S1 KL39: 0.983
#   Optical Gain of mode S2 KL104: 0.910
#   Optical Gain of mode S3 KL191: 0.876
#   Optical Gain of mode S4 KL317: 1.190
#   Optical Gain of mode S5 KL459: 0.888
#  iter: 686/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1962.0  Optical Gain of mode S0 KL6: 0.824
#   Optical Gain of mode S1 KL39: 0.607
#   Optical Gain of mode S2 KL104: 0.831
#   Optical Gain of mode S3 KL191: 0.823
#   Optical Gain of mode S4 KL317: 1.209
#   Optical Gain of mode S5 KL459: 1.289
#  iter: 735/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1948.3  Optical Gain of mode S0 KL6: 0.672
#   Optical Gain of mode S1 KL39: 1.013
#   Optical Gain of mode S2 KL104: 0.855
#   Optical Gain of mode S3 KL191: 0.468
#   Optical Gain of mode S4 KL317: 0.835
#   Optical Gain of mode S5 KL459: 0.906
#  iter: 784/1000, ET: 0.4 s, on-axis WF RMS [nm]: 1995.0  Optical Gain of mode S0 KL6: 0.876
#   Optical Gain of mode S1 KL39: 0.999
#   Optical Gain of mode S2 KL104: 1.001
#   Optical Gain of mode S3 KL191: 1.040
#   Optical Gain of mode S4 KL317: 0.682
#   Optical Gain of mode S5 KL459: 1.267
#  iter: 833/1000, ET: 0.4 s, on-axis WF RMS [nm]: 2017.7  Optical Gain of mode S0 KL6: 0.936
#   Optical Gain of mode S1 KL39: 0.642
#   Optical Gain of mode S2 KL104: 1.268
#   Optical Gain of mode S3 KL191: 0.973
#   Optical Gain of mode S4 KL317: 0.775
#   Optical Gain of mode S5 KL459: 1.418
#  iter: 882/1000, ET: 0.4 s, on-axis WF RMS [nm]: 2068.7  Optical Gain of mode S0 KL6: 1.104
#   Optical Gain of mode S1 KL39: 0.765
#   Optical Gain of mode S2 KL104: 0.811
#   Optical Gain of mode S3 KL191: 1.252
#   Optical Gain of mode S4 KL317: 0.714
#   Optical Gain of mode S5 KL459: 1.073
#  iter: 931/1000, ET: 0.4 s, on-axis WF RMS [nm]: 2100.3  Optical Gain of mode S0 KL6: 1.212
#   Optical Gain of mode S1 KL39: 0.921
#   Optical Gain of mode S2 KL104: 1.373
#   Optical Gain of mode S3 KL191: 1.073
#   Optical Gain of mode S4 KL317: 1.016
#   Optical Gain of mode S5 KL459: 0.592
#  iter: 980/1000, ET: 0.4 s, on-axis WF RMS [nm]: 2227.7  Optical Gain of mode S0 KL6: 0.992
#   Optical Gain of mode S1 KL39: 0.967
#   Optical Gain of mode S2 KL104: 0.631
#   Optical Gain of mode S3 KL191: 1.311
#   Optical Gain of mode S4 KL317: 0.494
#   Optical Gain of mode S5 KL459: 0.934
#  iter: 999/1000, ET: 0.4 s, on-axis WF RMS [nm]: 2272.8

# %%
inputFolder = '/home/frossi/CEO/'
parametersFileName = 'params'
ngaoSimulation1 = NGAO(inputFolder, parametersFileName)
ngaoSimulation1.loadTN('20210526_173108')
# Out:
# /home/frossi/CEO/params.ini
# M2 modes loaded from:512
# (@CEO)>Pyramid: Set modulation sampling to 24
# Number of NGAO GS photons/s/m^2: 2445999.8
# Number of expected NGAO GS photons [ph/s/m^2]: 2445652.2
# Number of pixels across 25.5-m array: 920

# %%
ngaoSimulation1.analyseSimulation()
# Out:
# Center of subpupil images (pix):
# [[117.5 117.5]
#  [117.5 249.5]
#  [249.5 117.5]
#  [249.5 249.5]]
# ->     Number of valid SAs: 5408
# (65536, 1350)
# RMS of KL mode 100 is: 0.51
# /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# Reading file: /raid1/gmt_data/CEO/NGAO_config/IM_KLsDD675_S7OC04184_PYR_thr0.336_mod2_SAv5408_px2.77cm_sep132.npz
# AO WFS - M2 Segment Modal IM:
# (10816, 4725)
#       Final WFE [nm RMS]: 1972.7
#       Final SPP RMS [nm]: 892.8
# Equivalent SR @ 1.65 um: 0.0000
